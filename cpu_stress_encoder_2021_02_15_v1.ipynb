# %% [markdown]
# -Added 2 layers to autoencoder
# -changed img input

# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
import matplotlib.pyplot as plt
from keras import backend as K
import numpy as np
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from PIL import Image, ImageChops
from sklearn.neighbors import KernelDensity
import random
import shutil
import tensorflow as tf

import glob

# %%
% matplotlib inline

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ls   #check if mounted correctly

DATADIR = "/content/gdrive/My Drive/cpu_stress_encoder"
os.listdir('/content/gdrive/My Drive/cpu_stress_encoder')     #show directories in base directory
# Out:
# Mounted at /content/gdrive
# gdrive	sample_data
# ['train', 'val']

# %%
Classes = ["idle_cpu"]

# %%
import random
for cl in Classes:
  img_path = os.path.join(DATADIR, cl)    # Merge DATADIR with class name
  print(img_path)
  images = glob.glob(img_path + '/*.jpg')   # Take path name and include everything with .jpg. Return list of all images
  random.shuffle(images)                    # randomly shuffle list
  print("{}: {} Images". format(cl,len(images)))
  num_train = int(round(len(images)*0.7))     # Find what 70% of images is
  train, val = images[:num_train], images[num_train:]   # Assign 70% and 30% of images to training and validation datasets respectively. list starting at index 0 up to but not including num_train

  for t in train:
    if not os.path.exists(os.path.join(DATADIR, 'train', cl)):
      os.makedirs(os.path.join(DATADIR, 'train', cl))
    shutil.move(t, os.path.join(DATADIR, 'train', cl))      # Move images to train directory

  for v in val:
    if not os.path.exists(os.path.join(DATADIR, 'val', cl)):
      os.makedirs(os.path.join(DATADIR, 'val', cl))
    shutil.move(v, os.path.join(DATADIR, 'val', cl))        #Move images to val director
# Out:
# /content/gdrive/My Drive/cpu_stress_encoder/idle_cpu
# idle_cpu: 1000 Images

# %%
batch_size = 64
IMG_width = 160
IMG_height= 160

# %%
train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
train_generator = train_datagen.flow_from_directory(
    '/content/gdrive/My Drive/cpu_stress_encoder/train/idle_cpu_autoencoder',
    target_size=(IMG_height, IMG_width),
    batch_size=batch_size,
    class_mode='input'
    )

val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
validation_generator = val_datagen.flow_from_directory(
    '/content/gdrive/My Drive/cpu_stress_encoder/val/idle_cpu_autoencoder',
    target_size=(IMG_height, IMG_width),
    batch_size=batch_size,
    class_mode='input'      #Use for Autoencoders because there is one class, its input and output
    )

anomaly_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
anomaly_generator = anomaly_datagen.flow_from_directory(
    '/content/gdrive/My Drive/cpu_stress_encoder/train/cpu_stress_autoencoder',
    target_size=(IMG_height, IMG_width),
    batch_size=batch_size,
    class_mode='input'
    )

images = glob.glob('/content/gdrive/My Drive/cpu_stress_encoder/train/idle_cpu_autoencoder/idle_cpu' + '/*.jpg')   # Take path name and include everything with .jpg. Return list of all images
print("{}: {} Images". format('train:idle_cpu_autoencoder',len(images)))

images = glob.glob('/content/gdrive/My Drive/cpu_stress_encoder/val/idle_cpu_autoencoder/idle_cpu' + '/*.jpg')   # Take path name and include everything with .jpg. Return list of all images
print("{}: {} Images". format('val:idle_cpu_autoencoder',len(images)))

images = glob.glob('/content/gdrive/My Drive/cpu_stress_encoder/train/cpu_stress_autoencoder/cpu_stress' + '/*.jpg')   # Take path name and include everything with .jpg. Return list of all images
print("{}: {} Images". format('test:cpu_stress_autoencoder',len(images)))
# Out:
# Found 700 images belonging to 1 classes.
# Found 300 images belonging to 1 classes.
# Found 1000 images belonging to 1 classes.
# train:idle_cpu_autoencoder: 700 Images
# val:idle_cpu_autoencoder: 300 Images
# test:cpu_stress_autoencoder: 1000 Images

# %%
# Define the convolutional autoencoder model 
# input shape must be the same size as the images that will be fed into it by the generators
# The output layer must be the same dimensions as the original image
model = Sequential()

model.add(Conv2D(16, (3, 3), padding='same',activation='relu', input_shape=(IMG_height, IMG_width, 3)))
model.add(MaxPooling2D(pool_size=(2,2), padding='same')) # using pool_size (2,2) makes the layer 2x smaller in height and width

model.add(Conv2D(8,(3, 3),activation='relu',  padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

model.add(Conv2D(3,(3, 3),activation='relu',  padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

model.add(Conv2D(3,(3, 3),activation='relu',  padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

#-------------------------

model.add(Conv2D(3,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(3,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(8,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(16,(3, 3),activation='relu',  padding='same'))
model.add(UpSampling2D((2, 2)))

model.add(Conv2D(3,(3, 3), activation='sigmoid', padding='same'))
#-------------------------

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 160, 160, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 80, 80, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 80, 80, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 40, 40, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 40, 40, 3)         219
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 3)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 3)         84
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 3)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 3)         84
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 20, 20, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 20, 3)         84
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 40, 40, 3)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 40, 40, 8)         224
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 80, 80, 8)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 80, 80, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 160, 160, 16)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 160, 160, 3)       435
# =================================================================
# Total params: 3,906
# Trainable params: 3,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Training the model
es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20) # Early stopping (stops training when validation doesn't improve for {patience} epochs).  min_delta=1 to abort if improvement is less than 1%. verbose displayes last epoch
model_filepath = 'models/cpu_stress_autoencoder.keras'
save_best = keras.callbacks.ModelCheckpoint(model_filepath, monitor='val_loss', save_best_only=True, mode='min',  verbose=1) # Saves the best version of the model to disk (as measured on the validation data set)
model.fit(
        train_generator,        #add accuracy metric
        steps_per_epoch=int(np.ceil(train_generator.n / float(batch_size))),
        epochs=600,
        validation_data=validation_generator,
        validation_steps=int(np.ceil(validation_generator.n / float(batch_size))),
        shuffle = True,
        callbacks=[es, save_best])
# Out:
# Epoch 1/600
# 11/11 [==============================] - 299s 27s/step - loss: 0.1211 - val_loss: 0.0981
#
# Epoch 00001: val_loss improved from inf to 0.09815, saving model to models/cpu_stress_autoencoder.keras
# Epoch 2/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0827 - val_loss: 0.0564
#
# Epoch 00002: val_loss improved from 0.09815 to 0.05644, saving model to models/cpu_stress_autoencoder.keras
# Epoch 3/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0515 - val_loss: 0.0431
#
# Epoch 00003: val_loss improved from 0.05644 to 0.04314, saving model to models/cpu_stress_autoencoder.keras
# Epoch 4/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0413 - val_loss: 0.0363
#
# Epoch 00004: val_loss improved from 0.04314 to 0.03633, saving model to models/cpu_stress_autoencoder.keras
# Epoch 5/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0353 - val_loss: 0.0316
#
# Epoch 00005: val_loss improved from 0.03633 to 0.03156, saving model to models/cpu_stress_autoencoder.keras
# Epoch 6/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0301 - val_loss: 0.0263
#
# Epoch 00006: val_loss improved from 0.03156 to 0.02628, saving model to models/cpu_stress_autoencoder.keras
# Epoch 7/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0253 - val_loss: 0.0228
#
# Epoch 00007: val_loss improved from 0.02628 to 0.02284, saving model to models/cpu_stress_autoencoder.keras
# Epoch 8/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0222 - val_loss: 0.0204
#
# Epoch 00008: val_loss improved from 0.02284 to 0.02038, saving model to models/cpu_stress_autoencoder.keras
# Epoch 9/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0198 - val_loss: 0.0185
#
# Epoch 00009: val_loss improved from 0.02038 to 0.01851, saving model to models/cpu_stress_autoencoder.keras
# Epoch 10/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0181 - val_loss: 0.0169
#
# Epoch 00010: val_loss improved from 0.01851 to 0.01687, saving model to models/cpu_stress_autoencoder.keras
# Epoch 11/600
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0164 - val_loss: 0.0149
#
# Epoch 00011: val_loss improved from 0.01687 to 0.01488, saving model to models/cpu_stress_autoencoder.keras
# Epoch 12/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0144 - val_loss: 0.0129
#
# Epoch 00012: val_loss improved from 0.01488 to 0.01290, saving model to models/cpu_stress_autoencoder.keras
# Epoch 13/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0125 - val_loss: 0.0115
#
# Epoch 00013: val_loss improved from 0.01290 to 0.01147, saving model to models/cpu_stress_autoencoder.keras
# Epoch 14/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0112 - val_loss: 0.0103
#
# Epoch 00014: val_loss improved from 0.01147 to 0.01031, saving model to models/cpu_stress_autoencoder.keras
# Epoch 15/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0102 - val_loss: 0.0094
#
# Epoch 00015: val_loss improved from 0.01031 to 0.00944, saving model to models/cpu_stress_autoencoder.keras
# Epoch 16/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0093 - val_loss: 0.0088
#
# Epoch 00016: val_loss improved from 0.00944 to 0.00877, saving model to models/cpu_stress_autoencoder.keras
# Epoch 17/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0086 - val_loss: 0.0082
#
# Epoch 00017: val_loss improved from 0.00877 to 0.00823, saving model to models/cpu_stress_autoencoder.keras
# Epoch 18/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0081 - val_loss: 0.0078
#
# Epoch 00018: val_loss improved from 0.00823 to 0.00782, saving model to models/cpu_stress_autoencoder.keras
# Epoch 19/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0078 - val_loss: 0.0074
#
# Epoch 00019: val_loss improved from 0.00782 to 0.00743, saving model to models/cpu_stress_autoencoder.keras
# Epoch 20/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0074 - val_loss: 0.0071
#
# Epoch 00020: val_loss improved from 0.00743 to 0.00714, saving model to models/cpu_stress_autoencoder.keras
# Epoch 21/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0071 - val_loss: 0.0069
#
# Epoch 00021: val_loss improved from 0.00714 to 0.00694, saving model to models/cpu_stress_autoencoder.keras
# Epoch 22/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0069 - val_loss: 0.0067
#
# Epoch 00022: val_loss improved from 0.00694 to 0.00671, saving model to models/cpu_stress_autoencoder.keras
# Epoch 23/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0067 - val_loss: 0.0066
#
# Epoch 00023: val_loss improved from 0.00671 to 0.00662, saving model to models/cpu_stress_autoencoder.keras
# Epoch 24/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0066 - val_loss: 0.0064
#
# Epoch 00024: val_loss improved from 0.00662 to 0.00642, saving model to models/cpu_stress_autoencoder.keras
# Epoch 25/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0064 - val_loss: 0.0063
#
# Epoch 00025: val_loss improved from 0.00642 to 0.00628, saving model to models/cpu_stress_autoencoder.keras
# Epoch 26/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0063 - val_loss: 0.0062
#
# Epoch 00026: val_loss improved from 0.00628 to 0.00617, saving model to models/cpu_stress_autoencoder.keras
# Epoch 27/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0062 - val_loss: 0.0061
#
# Epoch 00027: val_loss improved from 0.00617 to 0.00606, saving model to models/cpu_stress_autoencoder.keras
# Epoch 28/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0060 - val_loss: 0.0060
#
# Epoch 00028: val_loss improved from 0.00606 to 0.00600, saving model to models/cpu_stress_autoencoder.keras
# Epoch 29/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0060 - val_loss: 0.0059
#
# Epoch 00029: val_loss improved from 0.00600 to 0.00592, saving model to models/cpu_stress_autoencoder.keras
# Epoch 30/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0059 - val_loss: 0.0058
#
# Epoch 00030: val_loss improved from 0.00592 to 0.00579, saving model to models/cpu_stress_autoencoder.keras
# Epoch 31/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0058 - val_loss: 0.0057
#
# Epoch 00031: val_loss improved from 0.00579 to 0.00575, saving model to models/cpu_stress_autoencoder.keras
# Epoch 32/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0058 - val_loss: 0.0056
#
# Epoch 00032: val_loss improved from 0.00575 to 0.00562, saving model to models/cpu_stress_autoencoder.keras
# Epoch 33/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0056 - val_loss: 0.0055
#
# Epoch 00033: val_loss improved from 0.00562 to 0.00555, saving model to models/cpu_stress_autoencoder.keras
# Epoch 34/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0055 - val_loss: 0.0055
#
# Epoch 00034: val_loss improved from 0.00555 to 0.00546, saving model to models/cpu_stress_autoencoder.keras
# Epoch 35/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0055 - val_loss: 0.0054
#
# Epoch 00035: val_loss improved from 0.00546 to 0.00539, saving model to models/cpu_stress_autoencoder.keras
# Epoch 36/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0054 - val_loss: 0.0054
#
# Epoch 00036: val_loss improved from 0.00539 to 0.00537, saving model to models/cpu_stress_autoencoder.keras
# Epoch 37/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0054 - val_loss: 0.0054
#
# Epoch 00037: val_loss improved from 0.00537 to 0.00537, saving model to models/cpu_stress_autoencoder.keras
# Epoch 38/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0053 - val_loss: 0.0052
#
# Epoch 00038: val_loss improved from 0.00537 to 0.00517, saving model to models/cpu_stress_autoencoder.keras
# Epoch 39/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0052 - val_loss: 0.0051
#
# Epoch 00039: val_loss improved from 0.00517 to 0.00514, saving model to models/cpu_stress_autoencoder.keras
# Epoch 40/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0051 - val_loss: 0.0051
#
# Epoch 00040: val_loss improved from 0.00514 to 0.00509, saving model to models/cpu_stress_autoencoder.keras
# Epoch 41/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0051 - val_loss: 0.0050
#
# Epoch 00041: val_loss improved from 0.00509 to 0.00502, saving model to models/cpu_stress_autoencoder.keras
# Epoch 42/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0050 - val_loss: 0.0049
#
# Epoch 00042: val_loss improved from 0.00502 to 0.00495, saving model to models/cpu_stress_autoencoder.keras
# Epoch 43/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0050 - val_loss: 0.0049
#
# Epoch 00043: val_loss improved from 0.00495 to 0.00490, saving model to models/cpu_stress_autoencoder.keras
# Epoch 44/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0049 - val_loss: 0.0049
#
# Epoch 00044: val_loss improved from 0.00490 to 0.00488, saving model to models/cpu_stress_autoencoder.keras
# Epoch 45/600
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0049 - val_loss: 0.0048
#
# Epoch 00045: val_loss improved from 0.00488 to 0.00481, saving model to models/cpu_stress_autoencoder.keras
# Epoch 46/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0048 - val_loss: 0.0048
#
# Epoch 00046: val_loss improved from 0.00481 to 0.00477, saving model to models/cpu_stress_autoencoder.keras
# Epoch 47/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00047: val_loss improved from 0.00477 to 0.00474, saving model to models/cpu_stress_autoencoder.keras
# Epoch 48/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00048: val_loss did not improve from 0.00474
# Epoch 49/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0047 - val_loss: 0.0047
#
# Epoch 00049: val_loss improved from 0.00474 to 0.00466, saving model to models/cpu_stress_autoencoder.keras
# Epoch 50/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0047 - val_loss: 0.0046
#
# Epoch 00050: val_loss improved from 0.00466 to 0.00463, saving model to models/cpu_stress_autoencoder.keras
# Epoch 51/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0046 - val_loss: 0.0046
#
# Epoch 00051: val_loss improved from 0.00463 to 0.00461, saving model to models/cpu_stress_autoencoder.keras
# Epoch 52/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0046 - val_loss: 0.0046
#
# Epoch 00052: val_loss improved from 0.00461 to 0.00457, saving model to models/cpu_stress_autoencoder.keras
# Epoch 53/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0046 - val_loss: 0.0045
#
# Epoch 00053: val_loss improved from 0.00457 to 0.00453, saving model to models/cpu_stress_autoencoder.keras
# Epoch 54/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00054: val_loss improved from 0.00453 to 0.00451, saving model to models/cpu_stress_autoencoder.keras
# Epoch 55/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00055: val_loss did not improve from 0.00451
# Epoch 56/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00056: val_loss did not improve from 0.00451
# Epoch 57/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0045 - val_loss: 0.0045
#
# Epoch 00057: val_loss improved from 0.00451 to 0.00449, saving model to models/cpu_stress_autoencoder.keras
# Epoch 58/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0045 - val_loss: 0.0044
#
# Epoch 00058: val_loss improved from 0.00449 to 0.00440, saving model to models/cpu_stress_autoencoder.keras
# Epoch 59/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0044 - val_loss: 0.0044
#
# Epoch 00059: val_loss did not improve from 0.00440
# Epoch 60/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0044 - val_loss: 0.0044
#
# Epoch 00060: val_loss improved from 0.00440 to 0.00439, saving model to models/cpu_stress_autoencoder.keras
# Epoch 61/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0044 - val_loss: 0.0043
#
# Epoch 00061: val_loss improved from 0.00439 to 0.00434, saving model to models/cpu_stress_autoencoder.keras
# Epoch 62/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0043 - val_loss: 0.0043
#
# Epoch 00062: val_loss improved from 0.00434 to 0.00431, saving model to models/cpu_stress_autoencoder.keras
# Epoch 63/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0043 - val_loss: 0.0043
#
# Epoch 00063: val_loss improved from 0.00431 to 0.00429, saving model to models/cpu_stress_autoencoder.keras
# Epoch 64/600
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0043 - val_loss: 0.0043
#
# Epoch 00064: val_loss improved from 0.00429 to 0.00428, saving model to models/cpu_stress_autoencoder.keras
# Epoch 65/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0043 - val_loss: 0.0043
#
# Epoch 00065: val_loss improved from 0.00428 to 0.00427, saving model to models/cpu_stress_autoencoder.keras
# Epoch 66/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0043 - val_loss: 0.0042
#
# Epoch 00066: val_loss improved from 0.00427 to 0.00424, saving model to models/cpu_stress_autoencoder.keras
# Epoch 67/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0043 - val_loss: 0.0043
#
# Epoch 00067: val_loss did not improve from 0.00424
# Epoch 68/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0042 - val_loss: 0.0043
#
# Epoch 00068: val_loss did not improve from 0.00424
# Epoch 69/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00069: val_loss improved from 0.00424 to 0.00419, saving model to models/cpu_stress_autoencoder.keras
# Epoch 70/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00070: val_loss did not improve from 0.00419
# Epoch 71/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00071: val_loss improved from 0.00419 to 0.00417, saving model to models/cpu_stress_autoencoder.keras
# Epoch 72/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0042 - val_loss: 0.0041
#
# Epoch 00072: val_loss improved from 0.00417 to 0.00415, saving model to models/cpu_stress_autoencoder.keras
# Epoch 73/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0041 - val_loss: 0.0042
#
# Epoch 00073: val_loss did not improve from 0.00415
# Epoch 74/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00074: val_loss improved from 0.00415 to 0.00411, saving model to models/cpu_stress_autoencoder.keras
# Epoch 75/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00075: val_loss improved from 0.00411 to 0.00410, saving model to models/cpu_stress_autoencoder.keras
# Epoch 76/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00076: val_loss improved from 0.00410 to 0.00408, saving model to models/cpu_stress_autoencoder.keras
# Epoch 77/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00077: val_loss did not improve from 0.00408
# Epoch 78/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00078: val_loss did not improve from 0.00408
# Epoch 79/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00079: val_loss improved from 0.00408 to 0.00407, saving model to models/cpu_stress_autoencoder.keras
# Epoch 80/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00080: val_loss did not improve from 0.00407
# Epoch 81/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0041 - val_loss: 0.0041
#
# Epoch 00081: val_loss improved from 0.00407 to 0.00406, saving model to models/cpu_stress_autoencoder.keras
# Epoch 82/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0041 - val_loss: 0.0040
#
# Epoch 00082: val_loss improved from 0.00406 to 0.00401, saving model to models/cpu_stress_autoencoder.keras
# Epoch 83/600
# 11/11 [==============================] - 2s 199ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00083: val_loss improved from 0.00401 to 0.00400, saving model to models/cpu_stress_autoencoder.keras
# Epoch 84/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00084: val_loss improved from 0.00400 to 0.00398, saving model to models/cpu_stress_autoencoder.keras
# Epoch 85/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00085: val_loss improved from 0.00398 to 0.00397, saving model to models/cpu_stress_autoencoder.keras
# Epoch 86/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00086: val_loss improved from 0.00397 to 0.00396, saving model to models/cpu_stress_autoencoder.keras
# Epoch 87/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0040 - val_loss: 0.0040
#
# Epoch 00087: val_loss did not improve from 0.00396
# Epoch 88/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0040 - val_loss: 0.0039
#
# Epoch 00088: val_loss improved from 0.00396 to 0.00393, saving model to models/cpu_stress_autoencoder.keras
# Epoch 89/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00089: val_loss did not improve from 0.00393
# Epoch 90/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0040 - val_loss: 0.0039
#
# Epoch 00090: val_loss did not improve from 0.00393
# Epoch 91/600
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00091: val_loss improved from 0.00393 to 0.00392, saving model to models/cpu_stress_autoencoder.keras
# Epoch 92/600
# 11/11 [==============================] - 2s 220ms/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00092: val_loss improved from 0.00392 to 0.00388, saving model to models/cpu_stress_autoencoder.keras
# Epoch 93/600
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0039 - val_loss: 0.0040
#
# Epoch 00093: val_loss did not improve from 0.00388
# Epoch 94/600
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00094: val_loss improved from 0.00388 to 0.00386, saving model to models/cpu_stress_autoencoder.keras
# Epoch 95/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0039 - val_loss: 0.0039
#
# Epoch 00095: val_loss improved from 0.00386 to 0.00385, saving model to models/cpu_stress_autoencoder.keras
# Epoch 96/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00096: val_loss improved from 0.00385 to 0.00384, saving model to models/cpu_stress_autoencoder.keras
# Epoch 97/600
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00097: val_loss improved from 0.00384 to 0.00383, saving model to models/cpu_stress_autoencoder.keras
# Epoch 98/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0038 - val_loss: 0.0039
#
# Epoch 00098: val_loss did not improve from 0.00383
# Epoch 99/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00099: val_loss improved from 0.00383 to 0.00382, saving model to models/cpu_stress_autoencoder.keras
# Epoch 100/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00100: val_loss improved from 0.00382 to 0.00379, saving model to models/cpu_stress_autoencoder.keras
# Epoch 101/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00101: val_loss did not improve from 0.00379
# Epoch 102/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00102: val_loss improved from 0.00379 to 0.00379, saving model to models/cpu_stress_autoencoder.keras
# Epoch 103/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00103: val_loss did not improve from 0.00379
# Epoch 104/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00104: val_loss improved from 0.00379 to 0.00376, saving model to models/cpu_stress_autoencoder.keras
# Epoch 105/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0038 - val_loss: 0.0038
#
# Epoch 00105: val_loss did not improve from 0.00376
# Epoch 106/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0038 - val_loss: 0.0037
#
# Epoch 00106: val_loss improved from 0.00376 to 0.00373, saving model to models/cpu_stress_autoencoder.keras
# Epoch 107/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00107: val_loss improved from 0.00373 to 0.00373, saving model to models/cpu_stress_autoencoder.keras
# Epoch 108/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00108: val_loss improved from 0.00373 to 0.00371, saving model to models/cpu_stress_autoencoder.keras
# Epoch 109/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00109: val_loss improved from 0.00371 to 0.00371, saving model to models/cpu_stress_autoencoder.keras
# Epoch 110/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00110: val_loss improved from 0.00371 to 0.00369, saving model to models/cpu_stress_autoencoder.keras
# Epoch 111/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00111: val_loss improved from 0.00369 to 0.00369, saving model to models/cpu_stress_autoencoder.keras
# Epoch 112/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00112: val_loss did not improve from 0.00369
# Epoch 113/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0038 - val_loss: 0.0037
#
# Epoch 00113: val_loss did not improve from 0.00369
# Epoch 114/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0037 - val_loss: 0.0037
#
# Epoch 00114: val_loss improved from 0.00369 to 0.00366, saving model to models/cpu_stress_autoencoder.keras
# Epoch 115/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0037 - val_loss: 0.0036
#
# Epoch 00115: val_loss improved from 0.00366 to 0.00365, saving model to models/cpu_stress_autoencoder.keras
# Epoch 116/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0037 - val_loss: 0.0036
#
# Epoch 00116: val_loss improved from 0.00365 to 0.00364, saving model to models/cpu_stress_autoencoder.keras
# Epoch 117/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00117: val_loss improved from 0.00364 to 0.00363, saving model to models/cpu_stress_autoencoder.keras
# Epoch 118/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00118: val_loss did not improve from 0.00363
# Epoch 119/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00119: val_loss did not improve from 0.00363
# Epoch 120/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00120: val_loss improved from 0.00363 to 0.00361, saving model to models/cpu_stress_autoencoder.keras
# Epoch 121/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00121: val_loss did not improve from 0.00361
# Epoch 122/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00122: val_loss improved from 0.00361 to 0.00358, saving model to models/cpu_stress_autoencoder.keras
# Epoch 123/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00123: val_loss did not improve from 0.00358
# Epoch 124/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00124: val_loss improved from 0.00358 to 0.00357, saving model to models/cpu_stress_autoencoder.keras
# Epoch 125/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0036 - val_loss: 0.0036
#
# Epoch 00125: val_loss did not improve from 0.00357
# Epoch 126/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0036 - val_loss: 0.0035
#
# Epoch 00126: val_loss improved from 0.00357 to 0.00355, saving model to models/cpu_stress_autoencoder.keras
# Epoch 127/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00127: val_loss improved from 0.00355 to 0.00353, saving model to models/cpu_stress_autoencoder.keras
# Epoch 128/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0035 - val_loss: 0.0036
#
# Epoch 00128: val_loss did not improve from 0.00353
# Epoch 129/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0036 - val_loss: 0.0035
#
# Epoch 00129: val_loss improved from 0.00353 to 0.00352, saving model to models/cpu_stress_autoencoder.keras
# Epoch 130/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00130: val_loss did not improve from 0.00352
# Epoch 131/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0036 - val_loss: 0.0035
#
# Epoch 00131: val_loss improved from 0.00352 to 0.00351, saving model to models/cpu_stress_autoencoder.keras
# Epoch 132/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00132: val_loss did not improve from 0.00351
# Epoch 133/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00133: val_loss improved from 0.00351 to 0.00350, saving model to models/cpu_stress_autoencoder.keras
# Epoch 134/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00134: val_loss improved from 0.00350 to 0.00348, saving model to models/cpu_stress_autoencoder.keras
# Epoch 135/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00135: val_loss improved from 0.00348 to 0.00347, saving model to models/cpu_stress_autoencoder.keras
# Epoch 136/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00136: val_loss did not improve from 0.00347
# Epoch 137/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0035 - val_loss: 0.0036
#
# Epoch 00137: val_loss did not improve from 0.00347
# Epoch 138/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00138: val_loss improved from 0.00347 to 0.00345, saving model to models/cpu_stress_autoencoder.keras
# Epoch 139/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0035 - val_loss: 0.0035
#
# Epoch 00139: val_loss improved from 0.00345 to 0.00345, saving model to models/cpu_stress_autoencoder.keras
# Epoch 140/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0034 - val_loss: 0.0035
#
# Epoch 00140: val_loss did not improve from 0.00345
# Epoch 141/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0035 - val_loss: 0.0034
#
# Epoch 00141: val_loss improved from 0.00345 to 0.00343, saving model to models/cpu_stress_autoencoder.keras
# Epoch 142/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00142: val_loss improved from 0.00343 to 0.00343, saving model to models/cpu_stress_autoencoder.keras
# Epoch 143/600
# 11/11 [==============================] - 2s 216ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00143: val_loss did not improve from 0.00343
# Epoch 144/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00144: val_loss improved from 0.00343 to 0.00342, saving model to models/cpu_stress_autoencoder.keras
# Epoch 145/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00145: val_loss did not improve from 0.00342
# Epoch 146/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00146: val_loss improved from 0.00342 to 0.00340, saving model to models/cpu_stress_autoencoder.keras
# Epoch 147/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00147: val_loss improved from 0.00340 to 0.00340, saving model to models/cpu_stress_autoencoder.keras
# Epoch 148/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00148: val_loss did not improve from 0.00340
# Epoch 149/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00149: val_loss improved from 0.00340 to 0.00339, saving model to models/cpu_stress_autoencoder.keras
# Epoch 150/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00150: val_loss improved from 0.00339 to 0.00338, saving model to models/cpu_stress_autoencoder.keras
# Epoch 151/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00151: val_loss improved from 0.00338 to 0.00338, saving model to models/cpu_stress_autoencoder.keras
# Epoch 152/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00152: val_loss improved from 0.00338 to 0.00338, saving model to models/cpu_stress_autoencoder.keras
# Epoch 153/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00153: val_loss improved from 0.00338 to 0.00337, saving model to models/cpu_stress_autoencoder.keras
# Epoch 154/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0033 - val_loss: 0.0034
#
# Epoch 00154: val_loss did not improve from 0.00337
# Epoch 155/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00155: val_loss improved from 0.00337 to 0.00336, saving model to models/cpu_stress_autoencoder.keras
# Epoch 156/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00156: val_loss did not improve from 0.00336
# Epoch 157/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00157: val_loss improved from 0.00336 to 0.00335, saving model to models/cpu_stress_autoencoder.keras
# Epoch 158/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00158: val_loss improved from 0.00335 to 0.00335, saving model to models/cpu_stress_autoencoder.keras
# Epoch 159/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0034 - val_loss: 0.0034
#
# Epoch 00159: val_loss did not improve from 0.00335
# Epoch 160/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0034 - val_loss: 0.0033
#
# Epoch 00160: val_loss improved from 0.00335 to 0.00334, saving model to models/cpu_stress_autoencoder.keras
# Epoch 161/600
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00161: val_loss improved from 0.00334 to 0.00333, saving model to models/cpu_stress_autoencoder.keras
# Epoch 162/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0033 - val_loss: 0.0035
#
# Epoch 00162: val_loss did not improve from 0.00333
# Epoch 163/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0034 - val_loss: 0.0033
#
# Epoch 00163: val_loss improved from 0.00333 to 0.00332, saving model to models/cpu_stress_autoencoder.keras
# Epoch 164/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00164: val_loss did not improve from 0.00332
# Epoch 165/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00165: val_loss did not improve from 0.00332
# Epoch 166/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00166: val_loss improved from 0.00332 to 0.00331, saving model to models/cpu_stress_autoencoder.keras
# Epoch 167/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00167: val_loss improved from 0.00331 to 0.00330, saving model to models/cpu_stress_autoencoder.keras
# Epoch 168/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00168: val_loss did not improve from 0.00330
# Epoch 169/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00169: val_loss improved from 0.00330 to 0.00329, saving model to models/cpu_stress_autoencoder.keras
# Epoch 170/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00170: val_loss improved from 0.00329 to 0.00328, saving model to models/cpu_stress_autoencoder.keras
# Epoch 171/600
# 11/11 [==============================] - 2s 200ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00171: val_loss did not improve from 0.00328
# Epoch 172/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00172: val_loss improved from 0.00328 to 0.00328, saving model to models/cpu_stress_autoencoder.keras
# Epoch 173/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00173: val_loss improved from 0.00328 to 0.00327, saving model to models/cpu_stress_autoencoder.keras
# Epoch 174/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00174: val_loss improved from 0.00327 to 0.00327, saving model to models/cpu_stress_autoencoder.keras
# Epoch 175/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00175: val_loss improved from 0.00327 to 0.00326, saving model to models/cpu_stress_autoencoder.keras
# Epoch 176/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00176: val_loss did not improve from 0.00326
# Epoch 177/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00177: val_loss improved from 0.00326 to 0.00326, saving model to models/cpu_stress_autoencoder.keras
# Epoch 178/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00178: val_loss improved from 0.00326 to 0.00325, saving model to models/cpu_stress_autoencoder.keras
# Epoch 179/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0032 - val_loss: 0.0033
#
# Epoch 00179: val_loss did not improve from 0.00325
# Epoch 180/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0032 - val_loss: 0.0033
#
# Epoch 00180: val_loss did not improve from 0.00325
# Epoch 181/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0033 - val_loss: 0.0033
#
# Epoch 00181: val_loss did not improve from 0.00325
# Epoch 182/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0033 - val_loss: 0.0032
#
# Epoch 00182: val_loss improved from 0.00325 to 0.00324, saving model to models/cpu_stress_autoencoder.keras
# Epoch 183/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0033 - val_loss: 0.0032
#
# Epoch 00183: val_loss improved from 0.00324 to 0.00324, saving model to models/cpu_stress_autoencoder.keras
# Epoch 184/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00184: val_loss improved from 0.00324 to 0.00323, saving model to models/cpu_stress_autoencoder.keras
# Epoch 185/600
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00185: val_loss improved from 0.00323 to 0.00322, saving model to models/cpu_stress_autoencoder.keras
# Epoch 186/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00186: val_loss improved from 0.00322 to 0.00321, saving model to models/cpu_stress_autoencoder.keras
# Epoch 187/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0032 - val_loss: 0.0033
#
# Epoch 00187: val_loss did not improve from 0.00321
# Epoch 188/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00188: val_loss improved from 0.00321 to 0.00320, saving model to models/cpu_stress_autoencoder.keras
# Epoch 189/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00189: val_loss improved from 0.00320 to 0.00320, saving model to models/cpu_stress_autoencoder.keras
# Epoch 190/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00190: val_loss did not improve from 0.00320
# Epoch 191/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00191: val_loss improved from 0.00320 to 0.00318, saving model to models/cpu_stress_autoencoder.keras
# Epoch 192/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0033 - val_loss: 0.0032
#
# Epoch 00192: val_loss did not improve from 0.00318
# Epoch 193/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0032 - val_loss: 0.0032
#
# Epoch 00193: val_loss improved from 0.00318 to 0.00317, saving model to models/cpu_stress_autoencoder.keras
# Epoch 194/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0032 - val_loss: 0.0031
#
# Epoch 00194: val_loss improved from 0.00317 to 0.00315, saving model to models/cpu_stress_autoencoder.keras
# Epoch 195/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0031 - val_loss: 0.0031
#
# Epoch 00195: val_loss improved from 0.00315 to 0.00310, saving model to models/cpu_stress_autoencoder.keras
# Epoch 196/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0031 - val_loss: 0.0029
#
# Epoch 00196: val_loss improved from 0.00310 to 0.00294, saving model to models/cpu_stress_autoencoder.keras
# Epoch 197/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0029 - val_loss: 0.0029
#
# Epoch 00197: val_loss improved from 0.00294 to 0.00291, saving model to models/cpu_stress_autoencoder.keras
# Epoch 198/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0029 - val_loss: 0.0028
#
# Epoch 00198: val_loss improved from 0.00291 to 0.00276, saving model to models/cpu_stress_autoencoder.keras
# Epoch 199/600
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00199: val_loss improved from 0.00276 to 0.00269, saving model to models/cpu_stress_autoencoder.keras
# Epoch 200/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00200: val_loss improved from 0.00269 to 0.00269, saving model to models/cpu_stress_autoencoder.keras
# Epoch 201/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00201: val_loss improved from 0.00269 to 0.00266, saving model to models/cpu_stress_autoencoder.keras
# Epoch 202/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0027 - val_loss: 0.0026
#
# Epoch 00202: val_loss improved from 0.00266 to 0.00265, saving model to models/cpu_stress_autoencoder.keras
# Epoch 203/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00203: val_loss did not improve from 0.00265
# Epoch 204/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0027 - val_loss: 0.0027
#
# Epoch 00204: val_loss did not improve from 0.00265
# Epoch 205/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0027 - val_loss: 0.0026
#
# Epoch 00205: val_loss improved from 0.00265 to 0.00264, saving model to models/cpu_stress_autoencoder.keras
# Epoch 206/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00206: val_loss improved from 0.00264 to 0.00262, saving model to models/cpu_stress_autoencoder.keras
# Epoch 207/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00207: val_loss improved from 0.00262 to 0.00262, saving model to models/cpu_stress_autoencoder.keras
# Epoch 208/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00208: val_loss improved from 0.00262 to 0.00261, saving model to models/cpu_stress_autoencoder.keras
# Epoch 209/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00209: val_loss improved from 0.00261 to 0.00260, saving model to models/cpu_stress_autoencoder.keras
# Epoch 210/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00210: val_loss did not improve from 0.00260
# Epoch 211/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00211: val_loss did not improve from 0.00260
# Epoch 212/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00212: val_loss improved from 0.00260 to 0.00257, saving model to models/cpu_stress_autoencoder.keras
# Epoch 213/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0025 - val_loss: 0.0026
#
# Epoch 00213: val_loss improved from 0.00257 to 0.00256, saving model to models/cpu_stress_autoencoder.keras
# Epoch 214/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00214: val_loss improved from 0.00256 to 0.00255, saving model to models/cpu_stress_autoencoder.keras
# Epoch 215/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00215: val_loss improved from 0.00255 to 0.00254, saving model to models/cpu_stress_autoencoder.keras
# Epoch 216/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00216: val_loss improved from 0.00254 to 0.00252, saving model to models/cpu_stress_autoencoder.keras
# Epoch 217/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00217: val_loss did not improve from 0.00252
# Epoch 218/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0026 - val_loss: 0.0026
#
# Epoch 00218: val_loss did not improve from 0.00252
# Epoch 219/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0025 - val_loss: 0.0025
#
# Epoch 00219: val_loss improved from 0.00252 to 0.00251, saving model to models/cpu_stress_autoencoder.keras
# Epoch 220/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0025 - val_loss: 0.0024
#
# Epoch 00220: val_loss improved from 0.00251 to 0.00245, saving model to models/cpu_stress_autoencoder.keras
# Epoch 221/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00221: val_loss improved from 0.00245 to 0.00244, saving model to models/cpu_stress_autoencoder.keras
# Epoch 222/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00222: val_loss improved from 0.00244 to 0.00243, saving model to models/cpu_stress_autoencoder.keras
# Epoch 223/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00223: val_loss improved from 0.00243 to 0.00242, saving model to models/cpu_stress_autoencoder.keras
# Epoch 224/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00224: val_loss improved from 0.00242 to 0.00241, saving model to models/cpu_stress_autoencoder.keras
# Epoch 225/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00225: val_loss improved from 0.00241 to 0.00239, saving model to models/cpu_stress_autoencoder.keras
# Epoch 226/600
# 11/11 [==============================] - 2s 201ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00226: val_loss improved from 0.00239 to 0.00237, saving model to models/cpu_stress_autoencoder.keras
# Epoch 227/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00227: val_loss improved from 0.00237 to 0.00237, saving model to models/cpu_stress_autoencoder.keras
# Epoch 228/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00228: val_loss improved from 0.00237 to 0.00236, saving model to models/cpu_stress_autoencoder.keras
# Epoch 229/600
# 11/11 [==============================] - 2s 223ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00229: val_loss improved from 0.00236 to 0.00236, saving model to models/cpu_stress_autoencoder.keras
# Epoch 230/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0024 - val_loss: 0.0024
#
# Epoch 00230: val_loss improved from 0.00236 to 0.00235, saving model to models/cpu_stress_autoencoder.keras
# Epoch 231/600
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0024 - val_loss: 0.0023
#
# Epoch 00231: val_loss improved from 0.00235 to 0.00233, saving model to models/cpu_stress_autoencoder.keras
# Epoch 232/600
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00232: val_loss improved from 0.00233 to 0.00233, saving model to models/cpu_stress_autoencoder.keras
# Epoch 233/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00233: val_loss improved from 0.00233 to 0.00232, saving model to models/cpu_stress_autoencoder.keras
# Epoch 234/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00234: val_loss improved from 0.00232 to 0.00231, saving model to models/cpu_stress_autoencoder.keras
# Epoch 235/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00235: val_loss improved from 0.00231 to 0.00230, saving model to models/cpu_stress_autoencoder.keras
# Epoch 236/600
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00236: val_loss did not improve from 0.00230
# Epoch 237/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00237: val_loss did not improve from 0.00230
# Epoch 238/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00238: val_loss did not improve from 0.00230
# Epoch 239/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00239: val_loss improved from 0.00230 to 0.00228, saving model to models/cpu_stress_autoencoder.keras
# Epoch 240/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00240: val_loss improved from 0.00228 to 0.00228, saving model to models/cpu_stress_autoencoder.keras
# Epoch 241/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00241: val_loss improved from 0.00228 to 0.00227, saving model to models/cpu_stress_autoencoder.keras
# Epoch 242/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00242: val_loss did not improve from 0.00227
# Epoch 243/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0023 - val_loss: 0.0023
#
# Epoch 00243: val_loss improved from 0.00227 to 0.00226, saving model to models/cpu_stress_autoencoder.keras
# Epoch 244/600
# ...
# Epoch 507/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00507: val_loss did not improve from 0.00176
# Epoch 508/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00508: val_loss did not improve from 0.00176
# Epoch 509/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00509: val_loss did not improve from 0.00176
# Epoch 510/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00510: val_loss did not improve from 0.00176
# Epoch 511/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00511: val_loss did not improve from 0.00176
# Epoch 512/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00512: val_loss did not improve from 0.00176
# Epoch 513/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00513: val_loss did not improve from 0.00176
# Epoch 514/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00514: val_loss did not improve from 0.00176
# Epoch 515/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00515: val_loss did not improve from 0.00176
# Epoch 516/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00516: val_loss did not improve from 0.00176
# Epoch 517/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00517: val_loss improved from 0.00176 to 0.00175, saving model to models/cpu_stress_autoencoder.keras
# Epoch 518/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00518: val_loss improved from 0.00175 to 0.00175, saving model to models/cpu_stress_autoencoder.keras
# Epoch 519/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00519: val_loss improved from 0.00175 to 0.00174, saving model to models/cpu_stress_autoencoder.keras
# Epoch 520/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00520: val_loss improved from 0.00174 to 0.00174, saving model to models/cpu_stress_autoencoder.keras
# Epoch 521/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00521: val_loss did not improve from 0.00174
# Epoch 522/600
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00522: val_loss did not improve from 0.00174
# Epoch 523/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00523: val_loss did not improve from 0.00174
# Epoch 524/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0018 - val_loss: 0.0017
#
# Epoch 00524: val_loss did not improve from 0.00174
# Epoch 525/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00525: val_loss improved from 0.00174 to 0.00174, saving model to models/cpu_stress_autoencoder.keras
# Epoch 526/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00526: val_loss did not improve from 0.00174
# Epoch 527/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0018 - val_loss: 0.0017
#
# Epoch 00527: val_loss did not improve from 0.00174
# Epoch 528/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00528: val_loss did not improve from 0.00174
# Epoch 529/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00529: val_loss did not improve from 0.00174
# Epoch 530/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0017
#
# Epoch 00530: val_loss improved from 0.00174 to 0.00174, saving model to models/cpu_stress_autoencoder.keras
# Epoch 531/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00531: val_loss did not improve from 0.00174
# Epoch 532/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0018 - val_loss: 0.0017
#
# Epoch 00532: val_loss improved from 0.00174 to 0.00173, saving model to models/cpu_stress_autoencoder.keras
# Epoch 533/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00533: val_loss did not improve from 0.00173
# Epoch 534/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00534: val_loss did not improve from 0.00173
# Epoch 535/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00535: val_loss did not improve from 0.00173
# Epoch 536/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0018 - val_loss: 0.0018
#
# Epoch 00536: val_loss did not improve from 0.00173
# Epoch 537/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0018 - val_loss: 0.0017
#
# Epoch 00537: val_loss improved from 0.00173 to 0.00173, saving model to models/cpu_stress_autoencoder.keras
# Epoch 538/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00538: val_loss did not improve from 0.00173
# Epoch 539/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00539: val_loss did not improve from 0.00173
# Epoch 540/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00540: val_loss did not improve from 0.00173
# Epoch 541/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00541: val_loss improved from 0.00173 to 0.00173, saving model to models/cpu_stress_autoencoder.keras
# Epoch 542/600
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00542: val_loss did not improve from 0.00173
# Epoch 543/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00543: val_loss did not improve from 0.00173
# Epoch 544/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00544: val_loss did not improve from 0.00173
# Epoch 545/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00545: val_loss improved from 0.00173 to 0.00172, saving model to models/cpu_stress_autoencoder.keras
# Epoch 546/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00546: val_loss did not improve from 0.00172
# Epoch 547/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00547: val_loss did not improve from 0.00172
# Epoch 548/600
# 11/11 [==============================] - 2s 211ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00548: val_loss did not improve from 0.00172
# Epoch 549/600
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00549: val_loss improved from 0.00172 to 0.00172, saving model to models/cpu_stress_autoencoder.keras
# Epoch 550/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00550: val_loss did not improve from 0.00172
# Epoch 551/600
# 11/11 [==============================] - 2s 202ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00551: val_loss did not improve from 0.00172
# Epoch 552/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00552: val_loss improved from 0.00172 to 0.00172, saving model to models/cpu_stress_autoencoder.keras
# Epoch 553/600
# 11/11 [==============================] - 2s 212ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00553: val_loss did not improve from 0.00172
# Epoch 554/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00554: val_loss did not improve from 0.00172
# Epoch 555/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00555: val_loss did not improve from 0.00172
# Epoch 556/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00556: val_loss did not improve from 0.00172
# Epoch 557/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00557: val_loss did not improve from 0.00172
# Epoch 558/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00558: val_loss did not improve from 0.00172
# Epoch 559/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00559: val_loss improved from 0.00172 to 0.00171, saving model to models/cpu_stress_autoencoder.keras
# Epoch 560/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00560: val_loss did not improve from 0.00171
# Epoch 561/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00561: val_loss improved from 0.00171 to 0.00171, saving model to models/cpu_stress_autoencoder.keras
# Epoch 562/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00562: val_loss did not improve from 0.00171
# Epoch 563/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00563: val_loss did not improve from 0.00171
# Epoch 564/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00564: val_loss did not improve from 0.00171
# Epoch 565/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00565: val_loss did not improve from 0.00171
# Epoch 566/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00566: val_loss did not improve from 0.00171
# Epoch 567/600
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00567: val_loss improved from 0.00171 to 0.00171, saving model to models/cpu_stress_autoencoder.keras
# Epoch 568/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00568: val_loss improved from 0.00171 to 0.00170, saving model to models/cpu_stress_autoencoder.keras
# Epoch 569/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00569: val_loss did not improve from 0.00170
# Epoch 570/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00570: val_loss did not improve from 0.00170
# Epoch 571/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0018 - val_loss: 0.0017
#
# Epoch 00571: val_loss did not improve from 0.00170
# Epoch 572/600
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00572: val_loss did not improve from 0.00170
# Epoch 573/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00573: val_loss did not improve from 0.00170
# Epoch 574/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00574: val_loss did not improve from 0.00170
# Epoch 575/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00575: val_loss improved from 0.00170 to 0.00170, saving model to models/cpu_stress_autoencoder.keras
# Epoch 576/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00576: val_loss did not improve from 0.00170
# Epoch 577/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00577: val_loss improved from 0.00170 to 0.00170, saving model to models/cpu_stress_autoencoder.keras
# Epoch 578/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00578: val_loss improved from 0.00170 to 0.00169, saving model to models/cpu_stress_autoencoder.keras
# Epoch 579/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00579: val_loss did not improve from 0.00169
# Epoch 580/600
# 11/11 [==============================] - 2s 209ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00580: val_loss did not improve from 0.00169
# Epoch 581/600
# 11/11 [==============================] - 2s 214ms/step - loss: 0.0017 - val_loss: 0.0018
#
# Epoch 00581: val_loss did not improve from 0.00169
# Epoch 582/600
# 11/11 [==============================] - 2s 208ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00582: val_loss did not improve from 0.00169
# Epoch 583/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00583: val_loss improved from 0.00169 to 0.00169, saving model to models/cpu_stress_autoencoder.keras
# Epoch 584/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00584: val_loss did not improve from 0.00169
# Epoch 585/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00585: val_loss improved from 0.00169 to 0.00169, saving model to models/cpu_stress_autoencoder.keras
# Epoch 586/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00586: val_loss did not improve from 0.00169
# Epoch 587/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00587: val_loss did not improve from 0.00169
# Epoch 588/600
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00588: val_loss improved from 0.00169 to 0.00169, saving model to models/cpu_stress_autoencoder.keras
# Epoch 589/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00589: val_loss did not improve from 0.00169
# Epoch 590/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00590: val_loss did not improve from 0.00169
# Epoch 591/600
# 11/11 [==============================] - 2s 204ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00591: val_loss did not improve from 0.00169
# Epoch 592/600
# 11/11 [==============================] - 2s 205ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00592: val_loss did not improve from 0.00169
# Epoch 593/600
# 11/11 [==============================] - 2s 207ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00593: val_loss did not improve from 0.00169
# Epoch 594/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00594: val_loss did not improve from 0.00169
# Epoch 595/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00595: val_loss improved from 0.00169 to 0.00169, saving model to models/cpu_stress_autoencoder.keras
# Epoch 596/600
# 11/11 [==============================] - 2s 213ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00596: val_loss improved from 0.00169 to 0.00168, saving model to models/cpu_stress_autoencoder.keras
# Epoch 597/600
# 11/11 [==============================] - 2s 206ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00597: val_loss did not improve from 0.00168
# Epoch 598/600
# 11/11 [==============================] - 2s 203ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00598: val_loss did not improve from 0.00168
# Epoch 599/600
# 11/11 [==============================] - 2s 215ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00599: val_loss improved from 0.00168 to 0.00168, saving model to models/cpu_stress_autoencoder.keras
# Epoch 600/600
# 11/11 [==============================] - 2s 210ms/step - loss: 0.0017 - val_loss: 0.0017
#
# Epoch 00600: val_loss did not improve from 0.00168

# %%
# Training continues after improvement stops for the number of epochs equivalent to the 'patience' hyper-parameter
# To get back the model that performed best on the validation set we load the checkpointed model from disk:
# model = keras.models.load_model(model_filepath)
model = keras.models.load_model('./models/cpu_stress_autoencoder.keras')

# %%
model_filepath      #check model name

# %%
# Test the model by viewing a sample of original and reconstructed images of training dataset 
data_list = []
batch_index = 0
while batch_index <= train_generator.batch_index:
    data = train_generator.next()
    data_list.append(data[0])
    batch_index = batch_index + 1

predicted = model.predict(data_list[0])
no_of_samples = round(len(train_generator)/2)    #3 because thats how many objects in train_generator iterator
_, axs = plt.subplots(nrows=no_of_samples, ncols=2, figsize=(10, 16))   #axs is the location of the fig

axs = axs.flatten()
imgs = []
for i in range(no_of_samples):    
    imgs.append(data_list[i][i])
    imgs.append(predicted[i])


for img, ax in zip(imgs, axs):
    ax.imshow(img)
plt.show()

# %%
# Test the model by viewing a sample of original and reconstructed images of validation dataset
data_list = []
batch_index = 0
while batch_index <= validation_generator.batch_index:
    data = validation_generator.next()
    data_list.append(data[0])
    batch_index = batch_index + 1

predicted = model.predict(data_list[0])
no_of_samples = round(len(validation_generator)/2)        #3 because thats how many objects in train_generator iterator
_, axs = plt.subplots(nrows=no_of_samples, ncols=2, figsize=(10, 16))   #axs is the location of the fig

axs = axs.flatten()
imgs = []
for i in range(no_of_samples):    
    imgs.append(data_list[i][i])
    imgs.append(predicted[i])


for img, ax in zip(imgs, axs):
    ax.imshow(img)
plt.show()

# %%
# Test the model by viewing a sample of original and reconstructed images of anomaly dataset
data_list = []
batch_index = 0
while batch_index <= anomaly_generator.batch_index:
    data = anomaly_generator.next()
    data_list.append(data[0])
    batch_index = batch_index + 1

predicted = model.predict(data_list[0])
no_of_samples = round(len(anomaly_generator)/2)     #3 because thats how many objects in train_generator iterator
_, axs = plt.subplots(nrows=no_of_samples, ncols=2, figsize=(10, 16))   #axs is the location of the fig

axs = axs.flatten()
imgs = []
for i in range(no_of_samples):    
    imgs.append(data_list[i][i])
    imgs.append(predicted[i])


for img, ax in zip(imgs, axs):
    ax.imshow(img)
plt.show()

# %%
# We want the difference the difference in error between the validation (normal) images and anomalous images to be as high as possible
print(f"Error on validation set:{model.evaluate(validation_generator)}, error on anomaly set:{model.evaluate(anomaly_generator)}")
# Out:
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0017
# 16/16 [==============================] - 2s 141ms/step - loss: 0.0472
# Error on validation set:0.0016832537949085236, error on anomaly set:0.04717911034822464

# %%
# We build a replica of the first half of the auto-encoder (the encoder only)
# This network takes a an image which is 96x96x3 and compresses it down to a 3x3x3 tensor
encoder_replica = Sequential()
encoder_replica.add(Conv2D(16, (3, 3), padding='same',activation='relu', input_shape=(IMG_height, IMG_width, 3), weights=model.layers[0].get_weights(), name='encoder_conv_1') )    #get weights from original model
encoder_replica.add(MaxPooling2D(pool_size=(2,2), padding='same', name='encoder_maxpool_1'))
encoder_replica.add(Conv2D(8,(3, 3),activation='relu',  padding='same', weights=model.layers[2].get_weights(), name='encoder_conv_2'))
encoder_replica.add(MaxPooling2D(pool_size=(2,2), padding='same', name='encoder_maxpool_2'))
encoder_replica.add(Conv2D(3,(3, 3),activation='relu',  padding='same', weights=model.layers[4].get_weights(), name='encoder_conv_3'))
encoder_replica.add(MaxPooling2D(pool_size=(2,2), padding='same', name='encoder_maxpool_3'))
encoder_replica.add(Conv2D(3,(3, 3),activation='relu',  padding='same', weights=model.layers[6].get_weights(), name='encoder_conv_4'))
encoder_replica.add(MaxPooling2D(pool_size=(2,2), padding='same', name='encoder_maxpool_4'))
encoder_replica.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_conv_1 (Conv2D)      (None, 160, 160, 16)      448
# _________________________________________________________________
# encoder_maxpool_1 (MaxPoolin (None, 80, 80, 16)        0
# _________________________________________________________________
# encoder_conv_2 (Conv2D)      (None, 80, 80, 8)         1160
# _________________________________________________________________
# encoder_maxpool_2 (MaxPoolin (None, 40, 40, 8)         0
# _________________________________________________________________
# encoder_conv_3 (Conv2D)      (None, 40, 40, 3)         219
# _________________________________________________________________
# encoder_maxpool_3 (MaxPoolin (None, 20, 20, 3)         0
# _________________________________________________________________
# encoder_conv_4 (Conv2D)      (None, 20, 20, 3)         84
# _________________________________________________________________
# encoder_maxpool_4 (MaxPoolin (None, 10, 10, 3)         0
# =================================================================
# Total params: 1,911
# Trainable params: 1,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder_replica.compile(optimizer='adam', loss='mean_squared_error')

# %%
encoder_replica.save("cpu_stress_encoderr")
# Out:
# INFO:tensorflow:Assets written to: cpu_stress_encoderr/assets

# %%
#zip a folder under /content/Folder_To_Zip
# !zip -r /content/file.zip  /content/cpu_stress_encoderr
# Out:
#   adding: content/cpu_stress_encoderr/ (stored 0%)
#   adding: content/cpu_stress_encoderr/variables/ (stored 0%)
#   adding: content/cpu_stress_encoderr/variables/variables.index (deflated 54%)
#   adding: content/cpu_stress_encoderr/variables/variables.data-00000-of-00001 (deflated 30%)
#   adding: content/cpu_stress_encoderr/assets/ (stored 0%)
#   adding: content/cpu_stress_encoderr/saved_model.pb (deflated 90%)

# %%
# get dimensions of the last layer of 'encoder_replica' model
layer=encoder_replica.get_layer('encoder_maxpool_4')
layer_list=layer.get_output_at(0).get_shape().as_list()
dim= layer_list[1]*layer_list[2]*layer_list[3]



print("Last layer has dimensions: {}*{}*{}". format(layer_list[1],layer_list[2],layer_list[3]))
print("Product of layer dimensions: {}". format(dim))
# Out:
# Last layer has dimensions: 10*10*3
# Product of layer dimensions: 300

# %%
# Creating encoded (compressed versions of the training, validation and anomalous images) and getting their density
# The SKLearn kernel density function only works with 1D arrays so we need to flatten the tensors created by the encoder

encoded_images = encoder_replica.predict(train_generator)
encoded_images_flat = [np.reshape(img, (dim)) for img in encoded_images]      #to get the second argument multiply the dimensions in encoded_images: 12*12*3=432. Do this to flatten image

validation_encoded = encoder_replica.predict(validation_generator)
val_enc_flat = [np.reshape(img, (dim)) for img in validation_encoded]

anom_encoded = encoder_replica.predict(anomaly_generator)
anom_enc_flat = [np.reshape(img, (dim)) for img in anom_encoded]

# %%
np.savetxt("cpu_encoded_images_flat.csv", encoded_images_flat, delimiter=",")
np.savetxt("cpu_val_enc_flat.csv", val_enc_flat, delimiter=",")

# %%
# Kernel Density Estimation of the encoded vectors
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(encoded_images_flat)        # kernel density is a tool used to make discrete values smooth. bandwidth is how smooth it is. kernel is the function used. check https://mathisonian.github.io/kde/
training_density_scores = kde.score_samples(encoded_images_flat) 
print(np.median(training_density_scores))
print(training_density_scores)

validation_density_scores = kde.score_samples(val_enc_flat)
print(np.median(validation_density_scores))
print(validation_density_scores)

anomaly_density_scores = kde.score_samples(anom_enc_flat)
print(np.median(anomaly_density_scores))
print(anomaly_density_scores)



# Plotting the density distributions of the training (normal), validation (normal) and anomalous images
# Ideally we want to see high separation between the normal and anomalous classes
plt.figure(figsize = (10,7))
plt.title('Distribution of Density Scores')
plt.hist(training_density_scores, 12, alpha=0.5, label='Training Normal')
plt.hist(validation_density_scores, 12, alpha=0.5, label='Validation Normal')
plt.hist(anomaly_density_scores, 12, alpha=0.5, label='Anomalies')
plt.legend(loc='upper right')
plt.xlabel('Density Score')

plt.show()
# Out:
# 203.29251630150395
# [204.48834197 200.59901532 204.53713819 203.33618489 202.31461289
#  204.48579452 202.31341446 203.89192223 203.70480077 202.45521206
#  203.42942079 204.06701867 202.89064354 202.26039089 202.07396753
#  204.69918528 202.6608185  204.63374285 202.75690041 204.60541127
#  203.32670481 200.5987336  203.34085436 204.72307767 203.24378573
#  203.2837938  204.49461934 203.42251104 203.1636216  203.31671235
#  202.89966206 203.05763007 204.67997347 204.58655458 204.75450849
#  203.52731177 204.84809735 203.27292505 204.72206317 204.06679406
#  201.89785323 204.69503717 202.76725496 204.72466837 203.71692765
#  203.28454609 204.74371703 204.63448397 204.4212838  204.65533519
#  204.44546667 204.70313086 203.82154408 203.43190959 202.24390686
#  204.73286305 202.0846604  203.92265418 204.62016428 202.77702252
#  204.77383637 203.03241881 201.84193187 204.51518172 204.72046516
#  202.45904485 203.50958873 204.85751873 204.48135418 201.89747782
#  203.23930925 204.70938566 202.48454217 202.91624323 202.41457772
#  203.48637398 203.27210007 203.22249529 203.53740458 203.88827282
#  201.82030717 204.80829481 203.45370864 201.36255626 203.31670349
#  204.61950864 203.68103005 203.37601027 204.44745547 202.43647554
#  202.39830706 204.66871764 204.33486396 204.73768407 204.5055118
#  201.93006731 202.51296728 203.42881076 200.70728037 203.51958334
#  204.69728156 202.21547233 203.21469733 203.88041489 202.07596784
#  202.80517059 204.8110107  202.14898275 203.36307593 203.16191143
#  201.93144766 204.53437243 202.77471578 202.77096903 201.95711063
#  201.2027717  203.21057655 204.24133763 204.77249031 203.2114344
#  203.42938947 204.29231842 202.52308613 202.40788331 204.2055063
#  203.23535482 204.31289917 204.61246488 202.52323105 203.26380994
#  204.28789856 202.68224978 203.32291612 202.10097141 203.69496727
#  201.543201   202.9710448  202.7161583  204.27031316 202.55397804
#  202.64975364 204.79236702 204.49839273 202.17658808 200.77758603
#  202.75486511 202.78382416 202.51839351 204.79679854 204.81008483
#  204.57011584 202.87607156 204.67816639 202.78204987 204.74496325
#  203.30514618 202.93389701 204.61117351 203.00209948 202.05534583
#  204.67411456 204.08332502 201.48503561 204.7679125  204.85069116
#  204.35882815 202.21580783 202.72449027 203.01570525 202.00773978
#  203.73190409 203.36658652 202.44511231 202.53375146 204.69513154
#  204.70461461 202.96745634 203.78271812 203.42478695 204.60618708
#   31.56887767  62.53575006  12.20109414  69.86928765  64.66599849
#   85.2214132   85.52527249  87.08004906  13.93581554  17.01345669
#   87.13873362  71.28750565  42.41338612  65.29504908  27.84470157
#   65.64001632  17.07102689  86.06515027  66.97813414  38.86418491
#    3.57945651  16.19665673  59.92925166  54.73117159  27.33478449
#   38.11664141  59.90354925  47.44441819  53.59955382  31.25845114
#    5.98383755  85.42455051   6.16973911  41.6127271   62.72761541
#   59.15968286  81.05071419  64.96789032  51.66759515   6.41417923
#    3.63033328  27.73487019  73.07735757  84.17226343  62.38943956
#   47.43161103  57.29477547  25.22226187  50.15258549  86.72028809
#   57.76955342  70.07973322  60.63514532  84.6194186   21.60972515
#   85.79479519  86.77281152  62.25889221  85.05435605  61.33667625
#   58.37319501  49.71601591  37.18729905  59.37237661  56.17560178
#   87.73383273  -1.65252275  87.31113948  59.29968719  37.17854595
#   12.20993949  57.59271479  84.4470488   34.8324951   58.87575182
#   86.76412296  66.09671563  84.75818393  55.44415835  87.2872608
#   59.48345058  -3.82297102  56.77858592  68.79205191  36.38963668
#   59.99905414  54.90264631  64.21168263  88.32647094  85.88770234
#   11.97588014  39.80514569  84.7241562   88.1194006   87.53536476
#    8.5053523   60.13082937   8.95861304  55.63895366  13.18669606
#    3.89605677  85.13776921  14.54285308  68.26483981  59.40525364
#   71.10187718  59.90634755  85.25847996  87.87527239  86.34084714
#   83.01394051  64.51270404  86.19090485  57.65651797  66.67376526
#   67.51403859  85.84322702  64.26733311  61.74880584   0.17633917
#   11.55186484  86.46308082  49.24858326  85.07849945  60.48974968
#   87.01298867  88.56831136  49.46558494  60.53394689   8.60809855]

# %%
# sorted_validation_density_scores=np.sort(validation_density_scores)
# print(sorted_validation_density_scores)

min_quantile = np.quantile(validation_density_scores, 0.01)   #obtain 0.01 smallest value on validatation density score
max_quantile = np.quantile(validation_density_scores, 0.99)   #obtain 0.99 biggest value on validatation density score

min_quantile_threshold=min_quantile - 10          #change 10 to a number based on tolerance level
max_quantile_threshold= max_quantile + 10         #change 10 to a number based on tolerance level

# %%
# Create a function for classifying images in bulk (for testing purposes)
def get_mse(original, reconstruction):
    # Returns the mean square error for each image in the array
    return np.mean((original - reconstruction)**2, axis=(1,2,3)) 

def evaluate_model(test_file):
    # density_threshold = 175 # This threshold was chosen based on looking at the distribution of the density scores of the normal class (validation set)
    reconstruction_error_threshold = 0.020 # This threshold was chosen based on looking at the distribution of reconstruction errors of the normal class
    batch_size  = 0
    for (dirpath, dirnames, filenames) in os.walk(test_file):
        batch_size += len([file for file in filenames if file.endswith(".jpg")]) # Batchsize now is total images in folder
    
    test_img_generator = train_datagen.flow_from_directory(
    test_file,
    target_size=(IMG_height, IMG_width),
    batch_size=batch_size,
    class_mode='input'
    )
    
    images = test_img_generator.next()[0]   #load test images to variable images
    reconstructions = model.predict(images) #get reconstructed images
    MSEs = get_mse(images, reconstructions) #get mse
    reconstruction_anomalies = MSEs > reconstruction_error_threshold
    print(f'Reconstruction anomalies = {sum(reconstruction_anomalies)}')
    
    encoded_images = encoder_replica.predict(test_img_generator)
    encoded_images_flat = np.array([np.reshape(img, (dim)) for img in encoded_images])        #change argument (dim) to last layer dimensions product
    density_scores = kde.score_samples(encoded_images_flat)

    density_anomalies_min= density_scores < min_quantile_threshold      # check if desnity score is samller than threshold
    density_anomalies_max= density_scores > max_quantile_threshold      # check if desnity score is bigger than threshold
    density_anomalies = density_anomalies_min != density_anomalies_max    # get the resultant. example: density_anomalies_min= True,  density_anomalies_min= False ==> density_anomalies= True


    combined_anomalies = np.maximum(reconstruction_anomalies, density_anomalies)
    print(f'Combined anomalies = {sum(combined_anomalies)}')
    overall_detection_rate = sum(combined_anomalies) / len(combined_anomalies)
    print(f'Overall detection rate = {overall_detection_rate}')
    return  MSEs

# %%
# Check what proportion of normal images get classified as anomalous
MSE_normal=evaluate_model('/content/gdrive/My Drive/cpu_stress_encoder/train/idle_cpu_autoencoder')
# Out:
# Found 700 images belonging to 1 classes.
# Reconstruction anomalies = 0
# Combined anomalies = 0
# Overall detection rate = 0.0

# %%
# Check what proportion of validation images get classified as anomalous
MSE_val=evaluate_model('/content/gdrive/My Drive/cpu_stress_encoder/val/idle_cpu_autoencoder')
# Out:
# Found 300 images belonging to 1 classes.
# Reconstruction anomalies = 0
# Combined anomalies = 0
# Overall detection rate = 0.0

# %%
# Check what proportion of anomaly images (a set which was unseen in training) get classified as anomalous
MSE_anom=evaluate_model('/content/gdrive/My Drive/cpu_stress_encoder/train/cpu_stress_autoencoder')
# Out:
# Found 1000 images belonging to 1 classes.
# Reconstruction anomalies = 1000
# Combined anomalies = 1000
# Overall detection rate = 1.0

# %%
plt.figure(figsize = (10,7))
plt.title('Mean Squared Error Between Input and Output Image')
plt.hist(MSE_normal, 12, alpha=0.5, label='Training Normal')
plt.hist(MSE_val, 12, alpha=0.5, label='Validation Normal')
plt.hist(MSE_anom, 12, alpha=0.5, label='Anomalies')
plt.legend(loc='upper right')
plt.xlabel('MSE Score')

plt.show()

# %%
# This function can be used for ingference when the system is deployed it checks one image at a time
def check_anomaly(img_path):
    # density_threshold = 0 
    reconstruction_error_threshold = 0.020
    img  = Image.open(img_path)
    img = np.array(img.resize((IMG_height, IMG_width), Image.ANTIALIAS))
    img = img / 255
    img = tf.expand_dims(img, 0)

    encoded_img = encoder_replica.predict(img) # Create a compressed version of the image using the encoder
    encoded_img = [np.reshape(img, (dim)) for img in encoded_img] # Flatten the compressed image
    density = kde.score_samples(encoded_img)[0] # get a density score for the new image
    print(f'density: {density}')
    reconstruction = model.predict([[img]])
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)
    print(f'reconstruction_error: {reconstruction_error}')
    if density < min_quantile_threshold or density > max_quantile_threshold or reconstruction_error > reconstruction_error_threshold:
        print("This image is normal")
    else:
        print("This image is anomaly")

# %%
test_image = "/content/gdrive/My Drive/cpu_stress_encoder/train/cpu_stress_autoencoder/cpu_stress/FLIR2008Cropped.jpg"
check_anomaly(test_image)
# Out:
# density: 84.86099350178088
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0458
# reconstruction_error: 0.04577178135514259
# This image is anomaly
